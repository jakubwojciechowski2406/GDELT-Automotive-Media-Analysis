# %%
from gdeltnews.filtermerge import filtermerge

filtermerge(
    input_dir="gdeltpreprocessed",
    output_file="final_data_kuba.csv",
    query="BYD OR NIO OR XPeng OR Geely OR SAIC OR MG OR Tesla OR BMW OR Audi OR Mercedes OR Ford"
)
# Out:
# Filtering CSV files in gdeltpreprocessed into temporary file final_data_kuba.csv.tmp.
# Deduplicating by URL and writing final output to final_data_kuba.csv.
