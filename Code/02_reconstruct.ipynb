# %%
from multiprocessing import freeze_support
from gdeltnews.reconstruct import reconstruct

def main():
    reconstruct(
        input_dir="gdeltdata",
        output_dir="gdeltpreprocessed",
        language="en",
        url_filters=["motortrend.com", "caranddriver.com", "autocar.co.uk", "autonews.com", "motor1.com"],
        processes=10,  # use None for all available cores
    )

if __name__ == "__main__":
    freeze_support()  # important on Windows
    main()
# Out:
# Found 534 *.webngrams.json.gz files in gdeltdata
# Output CSV files will be written to gdeltpreprocessed
# Reconstructing:   0%|          | 0/534 [00:00<?, ?file/s]
# Processing 20260203000100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203000100.webngrams.json...
# Reconstructing:   0%|          | 1/534 [00:00<06:00,  1.48file/s]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203000100.webngrams.articles.csv
#
# Processing 20260203000200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203000200.webngrams.json...
# Reconstructing:   0%|          | 2/534 [00:05<26:43,  3.01s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203000200.webngrams.articles.csv
#
# Processing 20260203001700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203001700.webngrams.json...
# Reconstructing:   1%|          | 3/534 [00:10<35:03,  3.96s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203001700.webngrams.articles.csv
#
# Processing 20260203003200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203003200.webngrams.json...
# Reconstructing:   1%|          | 4/534 [00:15<38:50,  4.40s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203003200.webngrams.articles.csv
#
# Processing 20260203004700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203004700.webngrams.json...
# Reconstructing:   1%|          | 5/534 [00:20<41:08,  4.67s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203004700.webngrams.articles.csv
#
# Processing 20260203004800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203004800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203004800.webngrams.articles.csv
#
# Processing 20260203010200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203010200.webngrams.json...
# Reconstructing:   1%|▏         | 7/534 [00:25<30:16,  3.45s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203010200.webngrams.articles.csv
#
# Processing 20260203011700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203011700.webngrams.json...
# Reconstructing:   1%|▏         | 8/534 [00:29<32:23,  3.70s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203011700.webngrams.articles.csv
#
# Processing 20260203011800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203011800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203011800.webngrams.articles.csv
#
# Processing 20260203013200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203013200.webngrams.json...
# Reconstructing 2 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 2/2 [00:01<00:00,  1.55it/s]
# Reconstructing:   2%|▏         | 10/534 [00:36<30:40,  3.51s/file]
# Wrote 2 articles to gdeltpreprocessed/20260203013200.webngrams.articles.csv
#
# Processing 20260203014700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203014700.webngrams.json...
# Reconstructing:   2%|▏         | 11/534 [00:40<33:25,  3.84s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203014700.webngrams.articles.csv
#
# Processing 20260203014800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203014800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203014800.webngrams.articles.csv
#
# Processing 20260203020200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203020200.webngrams.json...
# Reconstructing 1 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 1/1 [00:00<00:00,  3.80it/s]
# Reconstructing:   2%|▏         | 13/534 [00:45<28:17,  3.26s/file]
# Wrote 1 articles to gdeltpreprocessed/20260203020200.webngrams.articles.csv
#
# Processing 20260203020300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203020300.webngrams.json...
# Reconstructing:   3%|▎         | 14/534 [00:46<23:43,  2.74s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203020300.webngrams.articles.csv
#
# Processing 20260203021700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203021700.webngrams.json...
# Reconstructing:   3%|▎         | 16/534 [00:51<20:28,  2.37s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203021700.webngrams.articles.csv
#
# Processing 20260203021800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203021800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203021800.webngrams.articles.csv
#
# Processing 20260203023200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203023200.webngrams.json...
# Reconstructing:   3%|▎         | 17/534 [00:56<26:20,  3.06s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203023200.webngrams.articles.csv
#
# Processing 20260203023300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203023300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203023300.webngrams.articles.csv
#
# Processing 20260203024700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203024700.webngrams.json...
# Reconstructing:   4%|▎         | 19/534 [01:00<22:16,  2.60s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203024700.webngrams.articles.csv
#
# Processing 20260203030200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203030200.webngrams.json...
# Reconstructing:   4%|▎         | 20/534 [01:05<27:32,  3.22s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203030200.webngrams.articles.csv
#
# Processing 20260203030300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203030300.webngrams.json...
# Reconstructing:   4%|▍         | 21/534 [01:05<21:23,  2.50s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203030300.webngrams.articles.csv
#
# Processing 20260203031700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203031700.webngrams.json...
# Reconstructing:   4%|▍         | 22/534 [01:10<27:08,  3.18s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203031700.webngrams.articles.csv
#
# Processing 20260203033200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203033200.webngrams.json...
# Reconstructing 1 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
# Reconstructing:   4%|▍         | 23/534 [01:17<34:53,  4.10s/file]
# Wrote 1 articles to gdeltpreprocessed/20260203033200.webngrams.articles.csv
#
# Processing 20260203033300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203033300.webngrams.json...
# Reconstructing:   4%|▍         | 24/534 [01:17<25:32,  3.00s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203033300.webngrams.articles.csv
#
# Processing 20260203034700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203034700.webngrams.json...
# Reconstructing:   5%|▍         | 25/534 [01:22<30:31,  3.60s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203034700.webngrams.articles.csv
#
# Processing 20260203040200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203040200.webngrams.json...
# Reconstructing:   5%|▍         | 26/534 [01:26<31:40,  3.74s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203040200.webngrams.articles.csv
#
# Processing 20260203041700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203041700.webngrams.json...
# Reconstructing:   5%|▌         | 27/534 [01:29<28:47,  3.41s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203041700.webngrams.articles.csv
#
# Processing 20260203041800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203041800.webngrams.json...
# Reconstructing:   5%|▌         | 28/534 [01:30<24:20,  2.89s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203041800.webngrams.articles.csv
#
# Processing 20260203043200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203043200.webngrams.json...
# Reconstructing:   5%|▌         | 29/534 [01:35<28:50,  3.43s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203043200.webngrams.articles.csv
#
# Processing 20260203043300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203043300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203043300.webngrams.articles.csv
#
# Processing 20260203044700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203044700.webngrams.json...
# Reconstructing:   6%|▌         | 31/534 [01:40<24:18,  2.90s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203044700.webngrams.articles.csv
#
# Processing 20260203050200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203050200.webngrams.json...
# Reconstructing:   6%|▌         | 32/534 [01:44<27:07,  3.24s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203050200.webngrams.articles.csv
#
# Processing 20260203050300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203050300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203050300.webngrams.articles.csv
#
# Processing 20260203051700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203051700.webngrams.json...
# Reconstructing:   6%|▋         | 34/534 [01:49<24:18,  2.92s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203051700.webngrams.articles.csv
#
# Processing 20260203053200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203053200.webngrams.json...
# Reconstructing 1 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# Reconstructing:   7%|▋         | 35/534 [01:55<30:08,  3.62s/file]
# Wrote 1 articles to gdeltpreprocessed/20260203053200.webngrams.articles.csv
#
# Processing 20260203054700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203054700.webngrams.json...
# Reconstructing:   7%|▋         | 36/534 [02:00<32:45,  3.95s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203054700.webngrams.articles.csv
#
# Processing 20260203060100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203060100.webngrams.json...
# Reconstructing:   7%|▋         | 37/534 [02:01<25:55,  3.13s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203060100.webngrams.articles.csv
#
# Processing 20260203060200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203060200.webngrams.json...
# Reconstructing:   7%|▋         | 38/534 [02:05<27:39,  3.35s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203060200.webngrams.articles.csv
#
# Processing 20260203061700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203061700.webngrams.json...
# Reconstructing:   7%|▋         | 39/534 [02:09<30:40,  3.72s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203061700.webngrams.articles.csv
#
# Processing 20260203061800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203061800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203061800.webngrams.articles.csv
#
# Processing 20260203063200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203063200.webngrams.json...
# Reconstructing:   8%|▊         | 42/534 [02:15<20:18,  2.48s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203063200.webngrams.articles.csv
#
# Processing 20260203063300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203063300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203063300.webngrams.articles.csv
#
# Processing 20260203064700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203064700.webngrams.json...
# Reconstructing:   8%|▊         | 43/534 [02:20<27:16,  3.33s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203064700.webngrams.articles.csv
#
# Processing 20260203070200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203070200.webngrams.json...
# Reconstructing:   8%|▊         | 44/534 [02:25<30:55,  3.79s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203070200.webngrams.articles.csv
#
# Processing 20260203070300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203070300.webngrams.json...
# Reconstructing:   8%|▊         | 45/534 [02:27<24:48,  3.04s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203070300.webngrams.articles.csv
#
# Processing 20260203071700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203071700.webngrams.json...
# Reconstructing:   9%|▊         | 46/534 [02:31<27:48,  3.42s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203071700.webngrams.articles.csv
#
# Processing 20260203071800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203071800.webngrams.json...
# Reconstructing:   9%|▉         | 47/534 [02:33<23:45,  2.93s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203071800.webngrams.articles.csv
#
# Processing 20260203073200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203073200.webngrams.json...
# Reconstructing:   9%|▉         | 48/534 [02:39<30:57,  3.82s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203073200.webngrams.articles.csv
#
# Processing 20260203074700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203074700.webngrams.json...
# Reconstructing:   9%|▉         | 49/534 [02:44<35:40,  4.41s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203074700.webngrams.articles.csv
#
# Processing 20260203074800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203074800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203074800.webngrams.articles.csv
#
# Processing 20260203080200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203080200.webngrams.json...
# Reconstructing:  10%|▉         | 51/534 [02:51<30:48,  3.83s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203080200.webngrams.articles.csv
#
# Processing 20260203081700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203081700.webngrams.json...
# Reconstructing:  10%|▉         | 52/534 [02:57<36:21,  4.53s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203081700.webngrams.articles.csv
#
# Processing 20260203081800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203081800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203081800.webngrams.articles.csv
#
# Processing 20260203083100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203083100.webngrams.json...
# Reconstructing:  10%|█         | 54/534 [03:00<26:23,  3.30s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203083100.webngrams.articles.csv
#
# Processing 20260203083200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203083200.webngrams.json...
# Reconstructing:  10%|█         | 55/534 [03:04<27:07,  3.40s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203083200.webngrams.articles.csv
#
# Processing 20260203084700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203084700.webngrams.json...
# Reconstructing:  11%|█         | 57/534 [03:11<25:08,  3.16s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203084700.webngrams.articles.csv
#
# Processing 20260203084800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203084800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203084800.webngrams.articles.csv
#
# Processing 20260203090100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203090100.webngrams.json...
# Reconstructing:  11%|█         | 58/534 [03:12<20:21,  2.57s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203090100.webngrams.articles.csv
#
# Processing 20260203090200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203090200.webngrams.json...
# Reconstructing:  11%|█         | 59/534 [03:18<28:14,  3.57s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203090200.webngrams.articles.csv
#
# Processing 20260203091700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203091700.webngrams.json...
# Reconstructing:  11%|█         | 60/534 [03:24<33:10,  4.20s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203091700.webngrams.articles.csv
#
# Processing 20260203091800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203091800.webngrams.json...
# Reconstructing:  11%|█▏        | 61/534 [03:25<25:24,  3.22s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203091800.webngrams.articles.csv
#
# Processing 20260203093100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203093100.webngrams.json...
# Reconstructing:  12%|█▏        | 62/534 [03:26<19:46,  2.51s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203093100.webngrams.articles.csv
#
# Processing 20260203093200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203093200.webngrams.json...
# Reconstructing:  12%|█▏        | 63/534 [03:31<26:51,  3.42s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203093200.webngrams.articles.csv
#
# Processing 20260203094700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203094700.webngrams.json...
# Reconstructing:  12%|█▏        | 65/534 [03:38<24:18,  3.11s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203094700.webngrams.articles.csv
#
# Processing 20260203094800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203094800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203094800.webngrams.articles.csv
#
# Processing 20260203100200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203100200.webngrams.json...
# Reconstructing:  12%|█▏        | 66/534 [03:42<25:49,  3.31s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203100200.webngrams.articles.csv
#
# Processing 20260203100300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203100300.webngrams.json...
# Reconstructing:  13%|█▎        | 67/534 [03:45<25:54,  3.33s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203100300.webngrams.articles.csv
#
# Processing 20260203101700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203101700.webngrams.json...
# Reconstructing:  13%|█▎        | 68/534 [03:52<33:13,  4.28s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203101700.webngrams.articles.csv
#
# Processing 20260203101800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203101800.webngrams.json...
# Reconstructing:  13%|█▎        | 69/534 [03:53<25:35,  3.30s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203101800.webngrams.articles.csv
#
# Processing 20260203103200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203103200.webngrams.json...
# Reconstructing:  13%|█▎        | 70/534 [03:59<32:16,  4.17s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203103200.webngrams.articles.csv
#
# Processing 20260203103300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203103300.webngrams.json...
# Reconstructing:  13%|█▎        | 71/534 [04:00<25:48,  3.34s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203103300.webngrams.articles.csv
#
# Processing 20260203104700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203104700.webngrams.json...
# Reconstructing 2 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
# Reconstructing:  13%|█▎        | 72/534 [04:08<36:13,  4.70s/file]
# Wrote 2 articles to gdeltpreprocessed/20260203104700.webngrams.articles.csv
#
# Processing 20260203104800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203104800.webngrams.json...
# Reconstructing:  14%|█▎        | 73/534 [04:09<26:25,  3.44s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203104800.webngrams.articles.csv
#
# Processing 20260203110200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203110200.webngrams.json...
# Reconstructing:  14%|█▍        | 74/534 [04:15<33:28,  4.37s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203110200.webngrams.articles.csv
#
# Processing 20260203110300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203110300.webngrams.json...
# Reconstructing:  14%|█▍        | 75/534 [04:16<25:01,  3.27s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203110300.webngrams.articles.csv
#
# Processing 20260203111700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203111700.webngrams.json...
# Reconstructing:  14%|█▍        | 76/534 [04:19<24:52,  3.26s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203111700.webngrams.articles.csv
#
# Processing 20260203111800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203111800.webngrams.json...
# Reconstructing:  14%|█▍        | 77/534 [04:24<28:48,  3.78s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203111800.webngrams.articles.csv
#
# Processing 20260203113200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203113200.webngrams.json...
# Reconstructing:  15%|█▍        | 79/534 [04:30<24:10,  3.19s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203113200.webngrams.articles.csv
#
# Processing 20260203113300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203113300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203113300.webngrams.articles.csv
#
# Processing 20260203114600.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203114600.webngrams.json...
# Reconstructing:  15%|█▍        | 80/534 [04:31<19:05,  2.52s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203114600.webngrams.articles.csv
#
# Processing 20260203114700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203114700.webngrams.json...
# Reconstructing:  15%|█▌        | 81/534 [04:37<26:10,  3.47s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203114700.webngrams.articles.csv
#
# Processing 20260203114800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203114800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203114800.webngrams.articles.csv
#
# Processing 20260203120100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203120100.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203120100.webngrams.articles.csv
#
# Processing 20260203120200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203120200.webngrams.json...
# Reconstructing:  16%|█▌        | 84/534 [04:44<21:18,  2.84s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203120200.webngrams.articles.csv
#
# Processing 20260203120300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203120300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203120300.webngrams.articles.csv
#
# Processing 20260203121700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203121700.webngrams.json...
# Reconstructing:  16%|█▌        | 86/534 [04:49<20:39,  2.77s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203121700.webngrams.articles.csv
#
# Processing 20260203121800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203121800.webngrams.json...
# Reconstructing:  16%|█▋        | 87/534 [04:53<22:35,  3.03s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203121800.webngrams.articles.csv
#
# Processing 20260203123200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203123200.webngrams.json...
# Reconstructing:  16%|█▋        | 88/534 [04:58<25:01,  3.37s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203123200.webngrams.articles.csv
#
# Processing 20260203123300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203123300.webngrams.json...
# Reconstructing:  17%|█▋        | 89/534 [05:01<24:39,  3.32s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203123300.webngrams.articles.csv
#
# Processing 20260203124700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203124700.webngrams.json...
# Reconstructing:  17%|█▋        | 90/534 [05:08<31:29,  4.26s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203124700.webngrams.articles.csv
#
# Processing 20260203124800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203124800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203124800.webngrams.articles.csv
#
# Processing 20260203130200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203130200.webngrams.json...
# Reconstructing:  17%|█▋        | 92/534 [05:15<28:59,  3.94s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203130200.webngrams.articles.csv
#
# Processing 20260203131700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203131700.webngrams.json...
# Reconstructing:  17%|█▋        | 93/534 [05:23<35:14,  4.79s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203131700.webngrams.articles.csv
#
# Processing 20260203131800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203131800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203131800.webngrams.articles.csv
#
# Processing 20260203133200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203133200.webngrams.json...
# Reconstructing:  18%|█▊        | 95/534 [05:26<25:42,  3.51s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203133200.webngrams.articles.csv
#
# Processing 20260203133300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203133300.webngrams.json...
# Reconstructing:  18%|█▊        | 96/534 [05:30<26:49,  3.68s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203133300.webngrams.articles.csv
#
# Processing 20260203134700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203134700.webngrams.json...
# Reconstructing:  18%|█▊        | 97/534 [05:33<25:02,  3.44s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203134700.webngrams.articles.csv
#
# Processing 20260203134800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203134800.webngrams.json...
# Reconstructing:  18%|█▊        | 98/534 [05:38<27:22,  3.77s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203134800.webngrams.articles.csv
#
# Processing 20260203134900.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203134900.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203134900.webngrams.articles.csv
#
# Processing 20260203140200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203140200.webngrams.json...
# Reconstructing:  19%|█▊        | 100/534 [05:45<26:26,  3.66s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203140200.webngrams.articles.csv
#
# Processing 20260203140300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203140300.webngrams.json...
# Reconstructing:  19%|█▉        | 101/534 [05:45<20:37,  2.86s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203140300.webngrams.articles.csv
#
# Processing 20260203141700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203141700.webngrams.json...
# Reconstructing:  19%|█▉        | 102/534 [05:51<26:15,  3.65s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203141700.webngrams.articles.csv
#
# Processing 20260203141800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203141800.webngrams.json...
# Reconstructing:  19%|█▉        | 103/534 [05:52<21:37,  3.01s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203141800.webngrams.articles.csv
#
# Processing 20260203143200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203143200.webngrams.json...
# Reconstructing:  19%|█▉        | 104/534 [05:58<26:46,  3.74s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203143200.webngrams.articles.csv
#
# Processing 20260203143300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203143300.webngrams.json...
# Reconstructing:  20%|█▉        | 105/534 [06:00<22:53,  3.20s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203143300.webngrams.articles.csv
#
# Processing 20260203144700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203144700.webngrams.json...
# Reconstructing:  20%|█▉        | 106/534 [06:07<31:48,  4.46s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203144700.webngrams.articles.csv
#
# Processing 20260203144800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203144800.webngrams.json...
# Reconstructing:  20%|██        | 107/534 [06:08<23:59,  3.37s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203144800.webngrams.articles.csv
#
# Processing 20260203150200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203150200.webngrams.json...
# Reconstructing:  20%|██        | 108/534 [06:12<24:31,  3.45s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203150200.webngrams.articles.csv
#
# Processing 20260203150300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203150300.webngrams.json...
# Reconstructing:  20%|██        | 109/534 [06:15<24:15,  3.43s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203150300.webngrams.articles.csv
#
# Processing 20260203151700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203151700.webngrams.json...
# Reconstructing 1 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
# Reconstructing:  21%|██        | 110/534 [06:19<26:32,  3.76s/file]
# Wrote 1 articles to gdeltpreprocessed/20260203151700.webngrams.articles.csv
#
# Processing 20260203151800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203151800.webngrams.json...
# Reconstructing 2 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 2/2 [00:01<00:00,  1.39it/s]
# Reconstructing:  21%|██        | 111/534 [06:24<27:31,  3.91s/file]
# Wrote 2 articles to gdeltpreprocessed/20260203151800.webngrams.articles.csv
#
# Processing 20260203153200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203153200.webngrams.json...
# Reconstructing:  21%|██        | 112/534 [06:27<26:50,  3.82s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203153200.webngrams.articles.csv
#
# Processing 20260203153300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203153300.webngrams.json...
# Reconstructing:  21%|██        | 113/534 [06:30<24:58,  3.56s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203153300.webngrams.articles.csv
#
# Processing 20260203154700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203154700.webngrams.json...
# Reconstructing:  21%|██▏       | 114/534 [06:33<23:11,  3.31s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203154700.webngrams.articles.csv
#
# Processing 20260203154800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203154800.webngrams.json...
# Reconstructing:  22%|██▏       | 115/534 [06:38<25:57,  3.72s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203154800.webngrams.articles.csv
#
# Processing 20260203160200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203160200.webngrams.json...
# Reconstructing:  22%|██▏       | 117/534 [06:45<22:55,  3.30s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203160200.webngrams.articles.csv
#
# Processing 20260203160300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203160300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203160300.webngrams.articles.csv
#
# Processing 20260203161600.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203161600.webngrams.json...
# Reconstructing:  22%|██▏       | 118/534 [06:45<16:36,  2.39s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203161600.webngrams.articles.csv
#
# Processing 20260203161700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203161700.webngrams.json...
# Reconstructing 2 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 2/2 [00:12<00:00,  6.26s/it]
# Reconstructing:  22%|██▏       | 120/534 [07:05<37:37,  5.45s/file]
# Wrote 2 articles to gdeltpreprocessed/20260203161700.webngrams.articles.csv
#
# Processing 20260203161800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203161800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203161800.webngrams.articles.csv
#
# Processing 20260203163200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203163200.webngrams.json...
# Reconstructing:  23%|██▎       | 121/534 [07:11<38:28,  5.59s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203163200.webngrams.articles.csv
#
# Processing 20260203163300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203163300.webngrams.json...
# Reconstructing:  23%|██▎       | 122/534 [07:13<30:15,  4.41s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203163300.webngrams.articles.csv
#
# Processing 20260203164700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203164700.webngrams.json...
# Reconstructing:  23%|██▎       | 123/534 [07:20<35:31,  5.19s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203164700.webngrams.articles.csv
#
# Processing 20260203164800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203164800.webngrams.json...
# Reconstructing:  23%|██▎       | 124/534 [07:20<26:08,  3.83s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203164800.webngrams.articles.csv
#
# Processing 20260203170200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203170200.webngrams.json...
# Reconstructing:  23%|██▎       | 125/534 [07:22<20:40,  3.03s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203170200.webngrams.articles.csv
#
# Processing 20260203170300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203170300.webngrams.json...
# Reconstructing:  24%|██▎       | 126/534 [07:28<26:58,  3.97s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203170300.webngrams.articles.csv
#
# Processing 20260203171700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203171700.webngrams.json...
# Reconstructing:  24%|██▍       | 127/534 [07:32<27:52,  4.11s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203171700.webngrams.articles.csv
#
# Processing 20260203171800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203171800.webngrams.json...
# Reconstructing:  24%|██▍       | 128/534 [07:35<25:39,  3.79s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203171800.webngrams.articles.csv
#
# Processing 20260203173200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203173200.webngrams.json...
# Reconstructing:  24%|██▍       | 129/534 [07:41<29:55,  4.43s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203173200.webngrams.articles.csv
#
# Processing 20260203173300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203173300.webngrams.json...
# Reconstructing:  24%|██▍       | 130/534 [07:43<25:01,  3.72s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203173300.webngrams.articles.csv
#
# Processing 20260203174700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203174700.webngrams.json...
# Reconstructing:  25%|██▍       | 131/534 [07:47<25:44,  3.83s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203174700.webngrams.articles.csv
#
# Processing 20260203174800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203174800.webngrams.json...
# Reconstructing:  25%|██▍       | 132/534 [07:51<24:42,  3.69s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203174800.webngrams.articles.csv
#
# Processing 20260203180200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203180200.webngrams.json...
# Reconstructing 3 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 3/3 [00:02<00:00,  1.12it/s]
# Reconstructing:  25%|██▍       | 133/534 [07:58<32:48,  4.91s/file]
# Wrote 3 articles to gdeltpreprocessed/20260203180200.webngrams.articles.csv
#
# Processing 20260203180300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203180300.webngrams.json...
# Reconstructing:  25%|██▌       | 134/534 [08:00<26:57,  4.04s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203180300.webngrams.articles.csv
#
# Processing 20260203181700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203181700.webngrams.json...
# Reconstructing:  25%|██▌       | 136/534 [08:07<22:25,  3.38s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203181700.webngrams.articles.csv
#
# Processing 20260203181800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203181800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203181800.webngrams.articles.csv
#
# Processing 20260203183200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203183200.webngrams.json...
# Reconstructing:  26%|██▌       | 137/534 [08:11<24:11,  3.66s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203183200.webngrams.articles.csv
#
# Processing 20260203183300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203183300.webngrams.json...
# Reconstructing:  26%|██▌       | 138/534 [08:14<21:10,  3.21s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203183300.webngrams.articles.csv
#
# Processing 20260203184600.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203184600.webngrams.json...
# Reconstructing:  26%|██▌       | 139/534 [08:14<15:28,  2.35s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203184600.webngrams.articles.csv
#
# Processing 20260203184700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203184700.webngrams.json...
# Reconstructing:  26%|██▌       | 140/534 [08:20<22:57,  3.50s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203184700.webngrams.articles.csv
#
# Processing 20260203184800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203184800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203184800.webngrams.articles.csv
#
# Processing 20260203190200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203190200.webngrams.json...
# Reconstructing:  27%|██▋       | 142/534 [08:26<20:39,  3.16s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203190200.webngrams.articles.csv
#
# Processing 20260203190300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203190300.webngrams.json...
# Reconstructing:  27%|██▋       | 143/534 [08:27<17:00,  2.61s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203190300.webngrams.articles.csv
#
# Processing 20260203191700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203191700.webngrams.json...
# Reconstructing:  27%|██▋       | 144/534 [08:31<20:01,  3.08s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203191700.webngrams.articles.csv
#
# Processing 20260203191800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203191800.webngrams.json...
# Reconstructing:  27%|██▋       | 145/534 [08:33<17:56,  2.77s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203191800.webngrams.articles.csv
#
# Processing 20260203193200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203193200.webngrams.json...
# Reconstructing:  28%|██▊       | 147/534 [08:40<18:38,  2.89s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203193200.webngrams.articles.csv
#
# Processing 20260203193300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203193300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203193300.webngrams.articles.csv
#
# Processing 20260203194700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203194700.webngrams.json...
# Reconstructing:  28%|██▊       | 148/534 [08:46<24:10,  3.76s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203194700.webngrams.articles.csv
#
# Processing 20260203194800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203194800.webngrams.json...
# Reconstructing:  28%|██▊       | 149/534 [08:46<17:29,  2.73s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203194800.webngrams.articles.csv
#
# Processing 20260203200200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203200200.webngrams.json...
# Reconstructing 3 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 3/3 [00:01<00:00,  2.38it/s]
# Reconstructing:  28%|██▊       | 150/534 [08:52<23:10,  3.62s/file]
# Wrote 3 articles to gdeltpreprocessed/20260203200200.webngrams.articles.csv
#
# Processing 20260203200300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203200300.webngrams.json...
# Reconstructing 1 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 1/1 [00:00<00:00,  5.98it/s]
# Reconstructing:  28%|██▊       | 151/534 [08:54<20:10,  3.16s/file]
# Wrote 1 articles to gdeltpreprocessed/20260203200300.webngrams.articles.csv
#
# Processing 20260203201700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203201700.webngrams.json...
# Reconstructing:  28%|██▊       | 152/534 [09:00<25:26,  4.00s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203201700.webngrams.articles.csv
#
# Processing 20260203203200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203203200.webngrams.json...
# Reconstructing:  29%|██▊       | 153/534 [09:06<29:29,  4.64s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203203200.webngrams.articles.csv
#
# Processing 20260203203300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203203300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203203300.webngrams.articles.csv
#
# Processing 20260203204700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203204700.webngrams.json...
# Reconstructing:  29%|██▉       | 155/534 [09:12<24:16,  3.84s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203204700.webngrams.articles.csv
#
# Processing 20260203210200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203210200.webngrams.json...
# Reconstructing:  29%|██▉       | 156/534 [09:17<26:36,  4.22s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203210200.webngrams.articles.csv
#
# Processing 20260203211700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203211700.webngrams.json...
# Reconstructing 1 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 1/1 [00:00<00:00,  2.59it/s]
# Reconstructing:  29%|██▉       | 157/534 [09:22<27:28,  4.37s/file]
# Wrote 1 articles to gdeltpreprocessed/20260203211700.webngrams.articles.csv
#
# Processing 20260203211800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203211800.webngrams.json...
# Reconstructing 2 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 2/2 [00:00<00:00,  5.93it/s]
# Reconstructing:  30%|██▉       | 158/534 [09:24<22:31,  3.59s/file]
# Wrote 2 articles to gdeltpreprocessed/20260203211800.webngrams.articles.csv
#
# Processing 20260203213100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203213100.webngrams.json...
# Reconstructing:  30%|██▉       | 159/534 [09:24<17:12,  2.75s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203213100.webngrams.articles.csv
#
# Processing 20260203213200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203213200.webngrams.json...
# Reconstructing:  30%|██▉       | 160/534 [09:29<21:09,  3.39s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203213200.webngrams.articles.csv
#
# Processing 20260203214700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203214700.webngrams.json...
# Reconstructing:  30%|███       | 161/534 [09:31<18:41,  3.01s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203214700.webngrams.articles.csv
#
# Processing 20260203214800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203214800.webngrams.json...
# Reconstructing:  30%|███       | 162/534 [09:35<19:04,  3.08s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203214800.webngrams.articles.csv
#
# Processing 20260203220200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203220200.webngrams.json...
# Reconstructing:  31%|███       | 163/534 [09:40<23:12,  3.75s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203220200.webngrams.articles.csv
#
# Processing 20260203220300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203220300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260203220300.webngrams.articles.csv
#
# Processing 20260203221700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260203221700.webngrams.json...
# Reconstructing 1 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 1/1 [00:00<00:00,  4.36it/s]
# Reconstructing:  31%|███       | 165/534 [09:45<18:58,  3.09s/file]
# Wrote 1 articles to gdeltpreprocessed/20260203221700.webngrams.articles.csv
#
# ...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205163300.webngrams.articles.csv
#
# Processing 20260205164700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205164700.webngrams.json...
# Reconstructing:  90%|████████▉ | 480/534 [27:53<04:07,  4.59s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205164700.webngrams.articles.csv
#
# Processing 20260205164800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205164800.webngrams.json...
# Reconstructing:  90%|█████████ | 481/534 [27:56<03:42,  4.19s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205164800.webngrams.articles.csv
#
# Processing 20260205170100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205170100.webngrams.json...
# Reconstructing:  90%|█████████ | 482/534 [27:57<02:42,  3.13s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205170100.webngrams.articles.csv
#
# Processing 20260205170200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205170200.webngrams.json...
# Reconstructing:  90%|█████████ | 483/534 [28:04<03:38,  4.28s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205170200.webngrams.articles.csv
#
# Processing 20260205170300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205170300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205170300.webngrams.articles.csv
#
# Processing 20260205171700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205171700.webngrams.json...
# Reconstructing:  91%|█████████ | 485/534 [28:11<03:15,  4.00s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205171700.webngrams.articles.csv
#
# Processing 20260205171800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205171800.webngrams.json...
# Reconstructing:  91%|█████████ | 486/534 [28:12<02:27,  3.06s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205171800.webngrams.articles.csv
#
# Processing 20260205173200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205173200.webngrams.json...
# Reconstructing:  91%|█████████ | 487/534 [28:17<02:57,  3.77s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205173200.webngrams.articles.csv
#
# Processing 20260205173300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205173300.webngrams.json...
# Reconstructing:  91%|█████████▏| 488/534 [28:19<02:20,  3.05s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205173300.webngrams.articles.csv
#
# Processing 20260205174600.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205174600.webngrams.json...
# Reconstructing:  92%|█████████▏| 489/534 [28:20<01:54,  2.56s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205174600.webngrams.articles.csv
#
# Processing 20260205174700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205174700.webngrams.json...
# Reconstructing:  92%|█████████▏| 490/534 [28:26<02:32,  3.46s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205174700.webngrams.articles.csv
#
# Processing 20260205180200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205180200.webngrams.json...
# Reconstructing:  92%|█████████▏| 491/534 [28:32<03:05,  4.32s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205180200.webngrams.articles.csv
#
# Processing 20260205180300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205180300.webngrams.json...
# Reconstructing:  92%|█████████▏| 492/534 [28:33<02:15,  3.22s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205180300.webngrams.articles.csv
#
# Processing 20260205181700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205181700.webngrams.json...
# Reconstructing:  92%|█████████▏| 493/534 [28:37<02:28,  3.62s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205181700.webngrams.articles.csv
#
# Processing 20260205181800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205181800.webngrams.json...
# Reconstructing:  93%|█████████▎| 494/534 [28:40<02:11,  3.29s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205181800.webngrams.articles.csv
#
# Processing 20260205183100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205183100.webngrams.json...
# Reconstructing:  93%|█████████▎| 495/534 [28:40<01:38,  2.53s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205183100.webngrams.articles.csv
#
# Processing 20260205183200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205183200.webngrams.json...
# Reconstructing:  93%|█████████▎| 496/534 [28:47<02:23,  3.77s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205183200.webngrams.articles.csv
#
# Processing 20260205184600.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205184600.webngrams.json...
# Reconstructing:  93%|█████████▎| 497/534 [28:48<01:46,  2.87s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205184600.webngrams.articles.csv
#
# Processing 20260205184700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205184700.webngrams.json...
# Reconstructing:  93%|█████████▎| 498/534 [28:54<02:16,  3.79s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205184700.webngrams.articles.csv
#
# Processing 20260205190100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205190100.webngrams.json...
# Reconstructing:  93%|█████████▎| 499/534 [28:55<01:46,  3.04s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205190100.webngrams.articles.csv
#
# Processing 20260205190200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205190200.webngrams.json...
# Reconstructing:  94%|█████████▎| 500/534 [29:01<02:10,  3.85s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205190200.webngrams.articles.csv
#
# Processing 20260205191600.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205191600.webngrams.json...
# Reconstructing:  94%|█████████▍| 501/534 [29:01<01:34,  2.86s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205191600.webngrams.articles.csv
#
# Processing 20260205191700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205191700.webngrams.json...
# Reconstructing:  94%|█████████▍| 502/534 [29:07<02:00,  3.77s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205191700.webngrams.articles.csv
#
# Processing 20260205193200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205193200.webngrams.json...
# Reconstructing:  94%|█████████▍| 503/534 [29:14<02:22,  4.58s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205193200.webngrams.articles.csv
#
# Processing 20260205193300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205193300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205193300.webngrams.articles.csv
#
# Processing 20260205194600.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205194600.webngrams.json...
# Reconstructing:  95%|█████████▍| 505/534 [29:14<01:15,  2.62s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205194600.webngrams.articles.csv
#
# Processing 20260205194700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205194700.webngrams.json...
# Reconstructing 5 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 5/5 [00:03<00:00,  1.40it/s]
# Reconstructing:  95%|█████████▍| 506/534 [29:24<01:59,  4.27s/file]
# Wrote 5 articles to gdeltpreprocessed/20260205194700.webngrams.articles.csv
#
# Processing 20260205194800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205194800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205194800.webngrams.articles.csv
#
# Processing 20260205200100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205200100.webngrams.json...
# Reconstructing:  95%|█████████▌| 508/534 [29:25<01:10,  2.72s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205200100.webngrams.articles.csv
#
# Processing 20260205200200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205200200.webngrams.json...
# Reconstructing:  95%|█████████▌| 509/534 [29:30<01:21,  3.25s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205200200.webngrams.articles.csv
#
# Processing 20260205201700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205201700.webngrams.json...
# Reconstructing:  96%|█████████▌| 510/534 [29:36<01:36,  4.00s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205201700.webngrams.articles.csv
#
# Processing 20260205203100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205203100.webngrams.json...
# Reconstructing:  96%|█████████▌| 511/534 [29:37<01:11,  3.11s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205203100.webngrams.articles.csv
#
# Processing 20260205203200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205203200.webngrams.json...
# Reconstructing:  96%|█████████▌| 512/534 [29:42<01:23,  3.81s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205203200.webngrams.articles.csv
#
# Processing 20260205204700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205204700.webngrams.json...
# Reconstructing 5 articles using 10 processes...
# Reconstructing articles: 100%|██████████| 5/5 [00:03<00:00,  1.30it/s]
# Reconstructing:  96%|█████████▌| 513/534 [29:52<01:55,  5.52s/file]
# Wrote 5 articles to gdeltpreprocessed/20260205204700.webngrams.articles.csv
#
# Processing 20260205210200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205210200.webngrams.json...
# Reconstructing:  96%|█████████▋| 514/534 [29:58<01:51,  5.59s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205210200.webngrams.articles.csv
#
# Processing 20260205210300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205210300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205210300.webngrams.articles.csv
#
# Processing 20260205211600.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205211600.webngrams.json...
# Reconstructing:  97%|█████████▋| 516/534 [29:59<00:58,  3.24s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205211600.webngrams.articles.csv
#
# Processing 20260205211700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205211700.webngrams.json...
# Reconstructing:  97%|█████████▋| 517/534 [30:04<01:03,  3.72s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205211700.webngrams.articles.csv
#
# Processing 20260205213200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205213200.webngrams.json...
# Reconstructing:  97%|█████████▋| 519/534 [30:10<00:46,  3.10s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205213200.webngrams.articles.csv
#
# Processing 20260205213300.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205213300.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205213300.webngrams.articles.csv
#
# Processing 20260205214700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205214700.webngrams.json...
# Reconstructing:  97%|█████████▋| 520/534 [30:16<00:54,  3.90s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205214700.webngrams.articles.csv
#
# Processing 20260205220200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205220200.webngrams.json...
# Reconstructing:  98%|█████████▊| 521/534 [30:21<00:56,  4.36s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205220200.webngrams.articles.csv
#
# Processing 20260205221700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205221700.webngrams.json...
# Reconstructing:  98%|█████████▊| 522/534 [30:27<00:57,  4.78s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205221700.webngrams.articles.csv
#
# Processing 20260205221800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205221800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205221800.webngrams.articles.csv
#
# Processing 20260205223100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205223100.webngrams.json...
# Reconstructing:  98%|█████████▊| 524/534 [30:28<00:27,  2.76s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205223100.webngrams.articles.csv
#
# Processing 20260205223200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205223200.webngrams.json...
# Reconstructing:  98%|█████████▊| 525/534 [30:32<00:28,  3.19s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205223200.webngrams.articles.csv
#
# Processing 20260205224700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205224700.webngrams.json...
# Reconstructing:  99%|█████████▊| 526/534 [30:37<00:29,  3.71s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205224700.webngrams.articles.csv
#
# Processing 20260205230200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205230200.webngrams.json...
# Reconstructing:  99%|█████████▊| 527/534 [30:42<00:28,  4.03s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205230200.webngrams.articles.csv
#
# Processing 20260205231600.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205231600.webngrams.json...
# Reconstructing:  99%|█████████▉| 528/534 [30:43<00:18,  3.09s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205231600.webngrams.articles.csv
#
# Processing 20260205231700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205231700.webngrams.json...
# Reconstructing:  99%|█████████▉| 529/534 [30:48<00:18,  3.64s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205231700.webngrams.articles.csv
#
# Processing 20260205231800.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205231800.webngrams.json...
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205231800.webngrams.articles.csv
#
# Processing 20260205233100.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205233100.webngrams.json...
# Reconstructing:  99%|█████████▉| 531/534 [30:48<00:06,  2.08s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205233100.webngrams.articles.csv
#
# Processing 20260205233200.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205233200.webngrams.json...
# Reconstructing: 100%|█████████▉| 532/534 [30:53<00:05,  2.75s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205233200.webngrams.articles.csv
#
# Processing 20260205234600.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205234600.webngrams.json...
# Reconstructing: 100%|█████████▉| 533/534 [30:54<00:02,  2.22s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205234600.webngrams.articles.csv
#
# Processing 20260205234700.webngrams.json.gz
# Loading and filtering data from gdeltdata/20260205234700.webngrams.json...
# Reconstructing: 100%|██████████| 534/534 [30:59<00:00,  3.48s/file]
# No articles found after filtering.
# Removed empty CSV (no articles): 20260205234700.webngrams.articles.csv
