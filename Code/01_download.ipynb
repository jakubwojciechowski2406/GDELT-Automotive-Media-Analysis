# %%
#https://iandreafc.github.io/gdeltnews/quickstart/

from gdeltnews.download import download

download(
    "2026-02-03T00:00:00",
    "2026-02-05T23:59:00",
    outdir="gdeltdata",
    decompress=False,
)
# Out:
# Time range from 2026-02-03 00:00:00 to 2026-02-05 23:59:00 covers 4320 minute slots.
# Target directory for downloads: gdeltdata
# Downloading: 100%|██████████| 4320/4320 [13:40<00:00,  5.26file/s]
# Downloaded 534 .gz files into gdeltdata.
# DownloadStats(requested_minutes=4320, downloaded_gz=534, decompressed_json=0)
